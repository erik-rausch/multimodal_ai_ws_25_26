# %%
# !pip install TTS
# !pip install -U numpy numba librosa soundfile

# %%
from TTS.api import TTS

# %%
tts = TTS("tts_models/de/thorsten/vits", progress_bar=False)

# %%
tts.tts_to_file(text="Hier ist ein langer Satz mit viel lustigem Zeug", file_path="output.wav")
